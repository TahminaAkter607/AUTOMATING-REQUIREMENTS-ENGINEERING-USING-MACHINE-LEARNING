# %% [markdown]
# BERT install

# %%
pip install sentence-transformers
# Out:
# ...
#      |████████████████████████████████| 85 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 48.7 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 56.5 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 29.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 77.0 MB/s
# ...
#      |████████████████████████████████| 636 kB 56.1 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.0.0-py3-none-any.whl size=126710 sha256=8c68483db64f1a92d300ae31174aacd35dc6f02d2cf67a66c3f055335a86aee1
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/0f/faafd427f705c4b012274ba60d9a91d75830306811e1355293
# Successfully built sentence-transformers
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/399 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# BERT Algorithm

# %%
#sentences = [
 #   "It is a system of library",
#    "School Management System for student",
 #   "Library Management Software",
 #   "Study Management Application"
#] 

def bertAlgo(sentences): 
   #print("123")
   a=[]
   sentence_embeddings = model.encode(sentences)
   sentence_embeddings.shape
   from sklearn.metrics.pairwise import cosine_similarity
   #print(cosine_similarity(
    #  [sentence_embeddings[0]],
    #  sentence_embeddings[1:]
   #))
   a.append(cosine_similarity(
      [sentence_embeddings[0]],
      sentence_embeddings[1:]
   ))
   return a[0][0].tolist()

# %% [markdown]
# CSV Reading

# %%
import csv
import itertools
filename = 'featurecsv.csv'

# %% [markdown]
# All Feature List

# %%
big=[]
small=[]
pid=1
input_list=[]
with open(filename, 'r') as csvfile:
    datareader = csv.reader(csvfile)
    
    for row in datareader:
       if int(row[0])==pid:
        #print(pid)
        small.append(row[2])
        #print(small)
       else:
        
        big.append(small)
        pid=pid+1
        #print(small)
        small=[]
        small.append(row[2])
        #print(small)
print(big)
sz=[];
s=0;
for i in range(len(big)):
  if(i==0):
    s=1;
    sz.append(s)
    continue

  s=s+len(big[i-1])
  sz.append(s)
print(sz)
# Out:
# [['Registration and Login', 'Dashboard', 'Look and Feel', 'Bidding Rules', 'Notification', 'Payment', 'Performance', 'Cross-Platform Support', 'Security', 'Session '], ['Instructor Rules', 'Instructor Rules', 'Passing Criteria', 'Functionality', 'Look and Feel', 'Intilligent Search ', 'Intilligent Search ', 'Availability'], ['Admin', 'Usability', 'Doctor', 'Doctor', 'Lab Technicians', 'Doctor', 'Data integrity', 'Admin', 'Cross Platform Support', 'Performance', 'Image'], ['Identify hotspot', 'Duration of presence', 'Attendance', 'Calculate attendence', 'Teacher', 'Session', 'Notification'], ['Security', 'Multiple Access ', 'Look and feel', 'Storage', 'Cross platform support', 'Admin', 'Registration ', 'Login', 'User', 'Search Election', 'Voting Criteria', 'Voting Result']]
# [1, 11, 19, 30, 37]

# %% [markdown]
# **Combinations & Input feature list**

# %%
for x,y in itertools.combinations(big, 2):
    print (x,y)
    feature1=x
    feature2=y
    p1=big.index(x)+1
    p2=big.index(y)+1
    f1_id_start=sz[big.index(x)]
    f2_id_start=sz[big.index(y)]
    for i in range(0,len(feature1)):
       #input_list.extend((feature+1,i+1,feature1[i],feature+2))
       input_list.append(feature1[i])
       input_list.extend(feature2)
       #print(input_list)
       score_list=bertAlgo(input_list)
       #inpt=[]
       #inpt.extend((feature+1,i+1,feature+2))
       outputList(input_list,score_list,p1,f1_id_start,p2,f2_id_start)
       f1_id_start=f1_id_start+1
       #f2_id_start=f2_id_start+1

       #print(score_list)
       input_list.clear()
# Out:
# ['Registration and Login', 'Dashboard', 'Look and Feel', 'Bidding Rules', 'Notification', 'Payment', 'Performance', 'Cross-Platform Support', 'Security', 'Session '] ['Instructor Rules', 'Instructor Rules', 'Passing Criteria', 'Functionality', 'Look and Feel', 'Intilligent Search ', 'Intilligent Search ', 'Availability']
# [[1, 1, 'Registration and Login', 2, 11, 'Instructor Rules', 0.6101775765419006], [1, 1, 'Registration and Login', 2, 12, 'Instructor Rules', 0.6101775765419006], [1, 1, 'Registration and Login', 2, 13, 'Passing Criteria', 0.565343976020813], [1, 1, 'Registration and Login', 2, 14, 'Functionality', 0.5881122946739197], [1, 1, 'Registration and Login', 2, 15, 'Look and Feel', 0.5964106917381287], [1, 1, 'Registration and Login', 2, 16, 'Intilligent Search ', 0.7136515378952026], [1, 1, 'Registration and Login', 2, 17, 'Intilligent Search ', 0.7136515378952026], [1, 1, 'Registration and Login', 2, 18, 'Availability', 0.5888882875442505]]
# ...

# %% [markdown]
# **Input Feature List**

# %%
"""
for feature in range(0,len(big)-1):
    feature1=big[feature]
    feature2=big[feature+1]
    #print(feature2)
    for i in range(0,len(feature1)):
       #input_list.extend((feature+1,i+1,feature1[i],feature+2))
       input_list.append(feature1[i])
       input_list.extend(feature2)
       #print(input_list)
       score_list=bertAlgo(input_list)
       #inpt=[]
       #inpt.extend((feature+1,i+1,feature+2))
       outputList(input_list,score_list,feature+1,i+1,feature+2)
       #print(score_list)
       input_list.clear()
    #i=i+1
    #input_list= feature1[0]+feature2[0::-1]
    
       #print(input_list)
      #input_list=feature[i]+featnext_feature[0::-1]
      #i++
      """
# Out:
# '\nfor feature in range(0,len(big)-1):\n    feature1=big[feature]\n    feature2=big[feature+1]\n    #print(feature2)\n    for i in range(0,len(feature1)):\n       #input_list.extend((feature+1,i+1,feature1[i],feature+2))\n       input_list.append(feature1[i])\n       input_list.extend(feature2)\n       #print(input_list)\n       score_list=bertAlgo(input_list)\n       #inpt=[]\n       #inpt.extend((feature+1,i+1,feature+2))\n       outputList(input_list,score_list,feature+1,i+1,feature+2)\n       #print(score_list)\n       input_list.clear()\n    #i=i+1\n    #input_list= feature1[0]+feature2[0::-1]\n    \n       #print(input_list)\n      #input_list=feature[i]+featnext_feature[0::-1]\n      #i++\n      '

# %% [markdown]
# **Output List**

# %%
#input_list=["hi","bye","ki","okay","thikase"]
def outputList(input_list,score_list,p1,f1_id,p2,f2_id):
    f2_id=f2_id
    big_output=[]
    small_output=[]
    for elem in range(1,len(input_list)):   
        small_output.extend([p1,f1_id,input_list[0],p2,f2_id,input_list[elem],score_list[elem-1]])
        f2_id=f2_id+1
        #print(small_output)
        big_output.append(small_output)
        #print(big_output)
        small_output=[]
        #f1_id_start=f1_id_start+1
        #small_output.clear()
        #print(small_output)
        #print(big_output)
    csvwrite(big_output)
    print(big_output)

# %% [markdown]
# **CSV Write**
#
# ---
#
#
#
# ---

# %%
def csvwrite(big_output):
    file = open('foo.csv', 'a', newline ='') 
    with file:     
       write = csv.writer(file)
       write.writerows(big_output)
